# %%
import numpy as np
import pymongo
from bson import ObjectId
from matplotlib import pyplot as plt 

client = pymongo.MongoClient("JFS-MAIN", 27017)
db = client['mt']
coll = db['lt_dat']
param_coll = db['lt_param']

stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('688eb1c6be48b8e3aa6af998')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    #disp_times = test_rec['disp_times']
    # disps = test_rec['disps']
    
    # #Convert displacement counts to mm. 
    # conv = 510 # Cal data showed sens. of 510 counts/mm
    # # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    # disp_red = []
    # disp_red_range = [(max(disps)), (min(disps))]
    # for disp in disps:
    #     if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
    #         new_disp = (max(disps)-disp)/conv
    #         disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load)
    n_loads = len(load_red)
    # n_disps = len(disp_red)
    # len_delt = n_loads - n_disps
    # if len_delt < 0:
    #     disp_red = disp_red[:len_delt]
    # elif len_delt > 0:
    #     load_red = load_red[:(-len_delt)]
    # else:
    #     pass
    plt.scatter(loadTimes, loads)
    
    test_loads = np.array(load_red)
    # test_disp_red = np.array(disp_red)
    # stiff, int = np.polyfit(disp_red, load_red, 1)
    # if test_rec['load_direction'] == "load":
    #     stiffness_loads.append(stiff)
    # elif test_rec['load_direction'] == "unload":
    #     stiffness_unloads.append(stiff)
    # print(f"The stiffness is: {stiff}")

# %%
  stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('662345262ca48b0c3053537c')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 510 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load)
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    plt.plot(disp_red, load_red)
    
    test_loads = np.array(load_red)
    test_disp_red = np.array(disp_red)
    stiff, int = np.polyfit(disp_red, load_red, 1)
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
    print(f"The stiffness is: {stiff}")
# Out:
# The stiffness is: 20.972354398680302
# The stiffness is: 20.28272223842491
# The stiffness is: 21.367138195171545
# The stiffness is: 20.224744842511328
# The stiffness is: 21.72121063832722
# The stiffness is: 20.2516084382465

# %%
stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('66230b2bf0ed41590eccb266')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 510 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load)
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        plt.plot(disp_red, load_red)
        
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
        print(f"The stiffness is: {stiff}")
# Out:
# The stiffness is: 18.539201500381335
# The stiffness is: 18.941290015755
# The stiffness is: 19.453277665367803
# The stiffness is: 19.039058240441822
# The stiffness is: 19.498717277954125

# %%
stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('662308289d2f0ce62c98b943')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 510 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load)
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        plt.plot(disp_red, load_red)
        
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
        print(f"The stiffness is: {stiff}")
# Out:
# The stiffness is: 19.448288932360043
# The stiffness is: 19.48447347680379
# The stiffness is: 19.180280880250777
# The stiffness is: 19.27704034230056
# The stiffness is: 20.144094442123688
# The stiffness is: 19.66646044448874
# The stiffness is: 20.49885476748283
# The stiffness is: 19.565568273471975
# The stiffness is: 21.5491611268019
# The stiffness is: 19.608534094074187
# The stiffness is: 20.278014457480328
# The stiffness is: 19.621442507412187
# The stiffness is: 21.97717251961584
# The stiffness is: 20.07489952441083
# The stiffness is: 21.25585649319881
# The stiffness is: 20.55593644151022
# The stiffness is: 20.490300142938104
# The stiffness is: 19.68200789993947
# The stiffness is: 21.305710721656375
# The stiffness is: 19.801911222743687
# The stiffness is: 20.262077438935314
# The stiffness is: 19.079210562857803

# %%
'''
Start of cells focused on simulation data
'''
part_name = "Outcome1"
outcome_1 = np.array([
    [0.5, 0.006],
    [1.0, 0.012],
    [1.5, 0.017],
    [2.0, 0.023],
    [2.5, 0.029],
    [3.0, 0.035],
    [3.5, 0.041],
    [4.0, 0.046],
    [4.5, 0.052],
    [5.0, 0.058],
    [5.5, 0.064],
    [6.0, 0.070],
    [6.5, 0.075],
    [7.0, 0.081],
    [7.5, 0.087],
    [8.0, 0.093],
    [8.5, 0.099],
    [9.0, 0.104],
    [9.5, 0.110],
    [10.0, 0.116]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_1:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1)
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
# Out:
# Stiffness of Outcome1: 86.29

# %%
stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('66233e095cb41a661af3a3be')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        plt.plot(disp_red, load_red)
    
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
    print(f"The stiffness is: {stiff}")
    
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('662308289d2f0ce62c98b943')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            plt.plot(disp_red, load_red)
        
            test_loads = np.array(load_red)
            test_disp_red = np.array(disp_red)
            stiff, int = np.polyfit(disp_red, load_red, 1)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
        print(f"The stiffness is: {stiff}")
        
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('66230b2bf0ed41590eccb266')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            plt.plot(disp_red, load_red)
        
            test_loads = np.array(load_red)
            test_disp_red = np.array(disp_red)
            stiff, int = np.polyfit(disp_red, load_red, 1)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
        print(f"The stiffness is: {stiff}")
        
# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('662345262ca48b0c3053537c')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        plt.plot(disp_red, load_red)
    
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
    print(f"The stiffness is: {stiff}")
# Out:
# The stiffness is: 34.110701497252364
# The stiffness is: 34.110701497252364
# The stiffness is: 32.787539407336446
# The stiffness is: 32.787539407336446
# The stiffness is: 32.92683624722085
# The stiffness is: 32.92683624722085
# The stiffness is: 32.92683624722085
# The stiffness is: 30.563879963613786
# The stiffness is: 30.563879963613786
# The stiffness is: 30.238494654589115
# The stiffness is: 30.238494654589115
# The stiffness is: 30.849349716845087
# The stiffness is: 30.849349716845087
# The stiffness is: 30.691087487799155
# The stiffness is: 30.691087487799155
# The stiffness is: 30.758484853449687
# The stiffness is: 30.758484853449687
# The stiffness is: 30.778733344960276
# The stiffness is: 30.778733344960276
# The stiffness is: 31.490038469664036
# The stiffness is: 31.490038469664036
# The stiffness is: 32.24460618276112
# The stiffness is: 32.24460618276112
# The stiffness is: 30.873737882258
# The stiffness is: 30.873737882258
# ...

# %%
np_stiff_loads = np.array(stiffness_loads)
np_stiff_unloads = np.array(stiffness_unloads)

loads_avg_stiff = np.average(np_stiff_loads)
unloads_avg_stiff = np.average(np_stiff_unloads)

loads_std_stiff = np.std(np_stiff_loads)
unloads_std_stiff = np.std(np_stiff_unloads)

print(f"Loading cycle Avg: {round(loads_avg_stiff,2)} with StdDev: {round(loads_std_stiff,3)}")
print(f"Unloading cycle Avg: {round(unloads_avg_stiff, 2)} with StdDev: {round(unloads_std_stiff,3)}")
# Out:
# Loading cycle Avg: 30.76 with StdDev: 3.03
# Unloading cycle Avg: 31.61 with StdDev: 1.397

# %%
stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('66233e095cb41a661af3a3be')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
        plt.plot(disp_red, load_red)
    
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
    print(f"The stiffness is: {stiff}")
    
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('662308289d2f0ce62c98b943')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
            plt.plot(disp_red, load_red)
        
            test_loads = np.array(load_red)
            test_disp_red = np.array(disp_red)
            stiff, int = np.polyfit(disp_red, load_red, 1)
        print(f"The stiffness is: {stiff}")
        
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('66230b2bf0ed41590eccb266')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
            plt.plot(disp_red, load_red)
        
            test_loads = np.array(load_red)
            test_disp_red = np.array(disp_red)
            stiff, int = np.polyfit(disp_red, load_red, 1)
        print(f"The stiffness is: {stiff}")
        
# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('662345262ca48b0c3053537c')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
        plt.plot(disp_red, load_red)
    
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
    print(f"The stiffness is: {stiff}")
# Out:
# The stiffness is: 34.07248727580745
# The stiffness is: 34.41513758261523
# The stiffness is: 34.41513758261523
# The stiffness is: 32.08611719142394
# The stiffness is: 32.08611719142394
# The stiffness is: 32.764360920885984
# The stiffness is: 30.5071198938981
# The stiffness is: 30.5071198938981
# The stiffness is: 30.086715106275722
# The stiffness is: 30.086715106275722
# The stiffness is: 31.598579517056773
# The stiffness is: 31.598579517056773
# The stiffness is: 32.15506630193386
# The stiffness is: 32.15506630193386
# The stiffness is: 33.802605689101014
# The stiffness is: 33.802605689101014
# The stiffness is: 31.808650129380915
# The stiffness is: 31.808650129380915
# The stiffness is: 34.47399610920131
# The stiffness is: 34.47399610920131
# The stiffness is: 33.342519989331464
# The stiffness is: 33.342519989331464
# The stiffness is: 32.141647283040136
# The stiffness is: 32.141647283040136
# The stiffness is: 33.42072270063748
# The stiffness is: 33.42072270063748
# ...

# %%
loads_full = []
loadsDisp_full = []
unloads_full = []
unloadsDisp_full = []
stiff_Loads = []
stiff_unloads = []

stiffness_loads = []
stiffness_unloads = []

# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('66233e095cb41a661af3a3be')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    plt.plot(disp_red, load_red)
    
    test_loads = np.array(load_red)
    test_disp_red = np.array(disp_red)
    stiff, int = np.polyfit(disp_red, load_red, 1)
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        loads_full.append(load_red)
        loadsDisp_full.append(disp_red)
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
        unloads_full.append(load_red)
        unloadsDisp_full.append(disp_red)
    print(f"The stiffness is: {stiff}")
    np_stiff_loads = np.array(stiffness_loads)
    np_stiff_unloads = np.array(stiffness_unloads)
    
    loads_avg_stiff = np.average(np_stiff_loads)
    unloads_avg_stiff = np.average(np_stiff_unloads)
    loads_std_stiff = np.std(np_stiff_loads)
    unloads_std_stiff = np.std(np_stiff_unloads)
    print(f"Loading cycle Avg: {round(loads_avg_stiff,2)} with StdDev: {round(loads_std_stiff,3)}")
    print(f"Unloading cycle Avg: {round(unloads_avg_stiff, 2)} with StdDev: {round(unloads_std_stiff,3)}")
    
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('662308289d2f0ce62c98b943')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
        
        plt.plot(disp_red, load_red)
    
        test_loads = np.array(load_red)
        test_disp_red = np.array(disp_red)
        stiff, int = np.polyfit(disp_red, load_red, 1)
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            loads_full.append(load_red)
            loadsDisp_full.append(disp_red)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
            unloads_full.append(load_red)
            unloadsDisp_full.append(disp_red)
        print(f"The stiffness is: {stiff}")
        
        np_stiff_loads = np.array(stiffness_loads)
        np_stiff_unloads = np.array(stiffness_unloads)
        
        loads_avg_stiff = np.average(np_stiff_loads)
        unloads_avg_stiff = np.average(np_stiff_unloads)
        loads_std_stiff = np.std(np_stiff_loads)
        unloads_std_stiff = np.std(np_stiff_unloads)
        print(f"Loading cycle Avg: {round(loads_avg_stiff,2)} with StdDev: {round(loads_std_stiff,3)}")
        print(f"Unloading cycle Avg: {round(unloads_avg_stiff, 2)} with StdDev: {round(unloads_std_stiff,3)}")
        
# Iterate over all test records for the desired test by param rec id
for count, test_rec in enumerate(coll.find({ "param_rec_id": ObjectId('66230b2bf0ed41590eccb266')})):
    if count > 0:
        #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
        
        loadTimes = test_rec['load_times']
        loads = test_rec['loads']
        disp_times = test_rec['disp_times']
        disps = test_rec['disps']
        
        #Convert displacement counts to mm. 
        conv = 800 # Cal data showed sens. of 510 counts/mm
        # For stiffness, remove bottom and top 10% of values to focus only on transient region.
        disp_red = []
        disp_red_range = [(max(disps)), (min(disps))]
        for disp in disps:
            if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
                new_disp = (max(disps)-disp)/conv
                disp_red.append(new_disp)
        load_red = []
        load_red_range = [(max(loads)), (min(loads))]
        for load in loads:
            if (load <= load_red_range[0]) and (load >= load_red_range[1]):
                load_red.append(load+abs(min(loads)))
        n_loads = len(load_red)
        n_disps = len(disp_red)
        len_delt = n_loads - n_disps
        if len_delt < 0:
            disp_red = disp_red[:len_delt]
        elif len_delt > 0:
            load_red = load_red[:(-len_delt)]
        else:
            pass
            plt.plot(disp_red, load_red)
        
            test_loads = np.array(load_red)
            test_disp_red = np.array(disp_red)
            stiff, int = np.polyfit(disp_red, load_red, 1)
        if test_rec['load_direction'] == "load":
            stiffness_loads.append(stiff)
            loads_full.append(load_red)
            loadsDisp_full.append(disp_red)
        elif test_rec['load_direction'] == "unload":
            stiffness_unloads.append(stiff)
            unloads_full.append(load_red)
            unloadsDisp_full.append(disp_red)

        print(f"The stiffness is: {stiff}")
        
        np_stiff_loads = np.array(stiffness_loads)
        np_stiff_unloads = np.array(stiffness_unloads)
        
        loads_avg_stiff = np.average(np_stiff_loads)
        unloads_avg_stiff = np.average(np_stiff_unloads)
        loads_std_stiff = np.std(np_stiff_loads)
        unloads_std_stiff = np.std(np_stiff_unloads)
        print(f"Loading cycle Avg: {round(loads_avg_stiff,2)} with StdDev: {round(loads_std_stiff,3)}")
        print(f"Unloading cycle Avg: {round(unloads_avg_stiff, 2)} with StdDev: {round(unloads_std_stiff,3)}")
        
# Iterate over all test records for the desired test by param rec id
for test_rec in coll.find({ "param_rec_id": ObjectId('662345262ca48b0c3053537c')}):

    #test_rec = coll.find_one({"_id": ObjectId('662345d82ca48b0c3053537f')})
    
    loadTimes = test_rec['load_times']
    loads = test_rec['loads']
    disp_times = test_rec['disp_times']
    disps = test_rec['disps']
    
    #Convert displacement counts to mm. 
    conv = 800 # Cal data showed sens. of 510 counts/mm
    # For stiffness, remove bottom and top 10% of values to focus only on transient region.
    disp_red = []
    disp_red_range = [(max(disps)), (min(disps))]
    for disp in disps:
        if (disp <= disp_red_range[0]) and (disp >= disp_red_range[1]):
            new_disp = (max(disps)-disp)/conv
            disp_red.append(new_disp)
    load_red = []
    load_red_range = [(max(loads)), (min(loads))]
    for load in loads:
        if (load <= load_red_range[0]) and (load >= load_red_range[1]):
            load_red.append(load+abs(min(loads)))
    n_loads = len(load_red)
    n_disps = len(disp_red)
    len_delt = n_loads - n_disps
    if len_delt < 0:
        disp_red = disp_red[:len_delt]
    elif len_delt > 0:
        load_red = load_red[:(-len_delt)]
    else:
        pass
    plt.plot(disp_red, load_red)
    
    test_loads = np.array(load_red)
    test_disp_red = np.array(disp_red)
    stiff, int = np.polyfit(disp_red, load_red, 1)
    if test_rec['load_direction'] == "load":
        stiffness_loads.append(stiff)
        loads_full.append(load_red)
        loadsDisp_full.append(disp_red)
    elif test_rec['load_direction'] == "unload":
        stiffness_unloads.append(stiff)
        unloads_full.append(load_red)
        unloadsDisp_full.append(disp_red)
        
    print(f"The stiffness is: {stiff}")
    plt.ylabel('Load (N)')
    plt.xlabel('Displacement (mm)')
    plt.title('Load vs Displacement - Outcome 3')
    np_stiff_loads = np.array(stiffness_loads)
    np_stiff_unloads = np.array(stiffness_unloads)
    
    loads_avg_stiff = np.average(np_stiff_loads)
    unloads_avg_stiff = np.average(np_stiff_unloads)
    loads_std_stiff = np.std(np_stiff_loads)
    unloads_std_stiff = np.std(np_stiff_unloads)
    print(f"Loading cycle Avg: {round(loads_avg_stiff,2)} with StdDev: {round(loads_std_stiff,3)}")
    print(f"Unloading cycle Avg: {round(unloads_avg_stiff, 2)} with StdDev: {round(unloads_std_stiff,3)}")
    
    '''
Start of cells focused on simulation data
'''
part_name = "Outcome1"
outcome_1 = np.array([
    [1.25, 0.018],
    [2.50, 0.037],
    [3.75, 0.055],
    [5.0, 0.073],
    [6.25, 0.092],
    [7.5, 0.110],
    [8.75, 0.128],
    [10.0, 0.147],
    [11.25, 0.165],
    [12.50, 0.183],
    [13.75, 0.202],
    [15.0, 0.220],
    [16.25, 0.238],
    [17.50, 0.257],
    [18.75, 0.275],
    [20.0, 0.293],
    [21.25, 0.312],
    [22.50, 0.330],
    [23.75, 0.348],
    [25.0, 0.367]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_1:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1)
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
# Out:
# The stiffness is: 34.110701497252364
# Loading cycle Avg: 34.11 with StdDev: 0.0
# Unloading cycle Avg: nan with StdDev: nan
# The stiffness is: 34.41513758261523
# Loading cycle Avg: 34.11 with StdDev: 0.0
# Unloading cycle Avg: 34.42 with StdDev: 0.0
# The stiffness is: 32.787539407336446
# Loading cycle Avg: 33.45 with StdDev: 0.662
# Unloading cycle Avg: 34.42 with StdDev: 0.0
# The stiffness is: 32.08611719142394
# Loading cycle Avg: 33.45 with StdDev: 0.662
# Unloading cycle Avg: 33.25 with StdDev: 1.165
# The stiffness is: 32.92683624722085
# Loading cycle Avg: 33.28 with StdDev: 0.594
# Unloading cycle Avg: 33.25 with StdDev: 1.165
# The stiffness is: 32.764360920885984
# Loading cycle Avg: 33.28 with StdDev: 0.594
# Unloading cycle Avg: 33.09 with StdDev: 0.978
# The stiffness is: 30.5071198938981
# Loading cycle Avg: 33.28 with StdDev: 0.594
# Unloading cycle Avg: 32.44 with StdDev: 1.402
# The stiffness is: 30.563879963613786
# Loading cycle Avg: 32.6 with StdDev: 1.282
# ...

# %%
l2 = []
d2 = []
ul2 = []
ud2 = []
outfile_jpg = './Load_v_Displacement_O3_'
outfile_png = './Load_v_Displacement_O3_'
fig, ax = plt.subplots(facecolor='dimgrey')
plt.title('Load vs Deflection - Outcome3')
plt.ylabel('Load (N)')
plt.xlabel('Displacement (mm)')
ax.set_facecolor('lightslategrey')
for inc, set in enumerate(loads_full):
    for inc2, item in enumerate(set):
        l2.append(item)
        d2.append(loadsDisp_full[inc][inc2])
    ax.scatter(d2, l2, marker='.', color='black')
    if inc == 0:
        ax.set_label('Measured')
    outname = f'{outfile_png}{inc}.png'
    outname2 = f'{outfile_jpg}{inc}.jpg'
    plt.savefig(outname)
    plt.savefig(outname2)
m, b = np.polyfit(d2, l2, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
ax.axline((0,b), slope=m, color='red', label='Linear Fit')

plt.savefig('./wFit.jpg')

plt.plot(sim_disps_1, sim_loads_1, label='Sim Values', color="brown", marker=",")
ax.legend()
plt.savefig('./wSim.png')
# Out:
# Stiffness of Outcome3: 33.6

# %%
'''
Start of cells focused on simulation data
'''
part_name = "Outcome1"
outcome_1 = np.array([
    [0.5, 0.006],
    [1.0, 0.012],
    [1.5, 0.017],
    [2.0, 0.023],
    [2.5, 0.029],
    [3.0, 0.035],
    [3.5, 0.041],
    [4.0, 0.046],
    [4.5, 0.052],
    [5.0, 0.058],
    [5.5, 0.064],
    [6.0, 0.070],
    [6.5, 0.075],
    [7.0, 0.081],
    [7.5, 0.087],
    [8.0, 0.093],
    [8.5, 0.099],
    [9.0, 0.104],
    [9.5, 0.110],
    [10.0, 0.116]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_1:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1, label='Outcome 1')
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
'''
Start of cells focused on simulation data
'''
part_name = "Outcome2"
outcome_2 = np.array([
    [0.5, 0.005],
    [1.0, 0.011],
    [1.5, 0.016],
    [2.0, 0.021],
    [2.5, 0.027],
    [3.0, 0.032],
    [3.5, 0.037],
    [4.0, 0.043],
    [4.5, 0.048],
    [5.0, 0.053],
    [5.5, 0.059],
    [6.0, 0.064],
    [6.5, 0.069],
    [7.0, 0.075],
    [7.5, 0.080],
    [8.0, 0.086],
    [8.5, 0.091],
    [9.0, 0.096],
    [9.5, 0.102],
    [10.0, 0.107]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_2:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1, label='Outcome 2')
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
'''
Start of cells focused on simulation data
'''
part_name = "Outcome3"
outcome_3 = np.array([
    [0.5, 0.007],
    [1.0, 0.015],
    [1.5, 0.022],
    [2.0, 0.029],
    [2.5, 0.037],
    [3.0, 0.044],
    [3.5, 0.051],
    [4.0, 0.059],
    [4.5, 0.066],
    [5.0, 0.073],
    [5.5, 0.081],
    [6.0, 0.088],
    [6.5, 0.095],
    [7.0, 0.103],
    [7.5, 0.110],
    [8.0, 0.117],
    [8.5, 0.125],
    [9.0, 0.132],
    [9.5, 0.139],
    [10.0, 0.147]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_3:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1, label='Outcome 3')
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
'''
Start of cells focused on simulation data
'''
part_name = "Outcome4"
outcome_4 = np.array([
    [0.5, 0.007],
    [1.0, 0.015],
    [1.5, 0.022],
    [2.0, 0.030],
    [2.5, 0.037],
    [3.0, 0.045],
    [3.5, 0.052],
    [4.0, 0.059],
    [4.5, 0.067],
    [5.0, 0.074],
    [5.5, 0.082],
    [6.0, 0.089],
    [6.5, 0.097],
    [7.0, 0.104],
    [7.5, 0.111],
    [8.0, 0.119],
    [8.5, 0.126],
    [9.0, 0.134],
    [9.5, 0.141],
    [10.0, 0.149]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_4:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1, label='Outcome 4')
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")

plt.ylabel('Load (N)')
plt.xlabel('Displacement (mm)')
plt.legend()
plt.title('Load vs Displacement - Simulations')
# Out:
# Stiffness of Outcome1: 86.29
# Stiffness of Outcome2: 93.31
# Stiffness of Outcome3: 68.15
# Stiffness of Outcome4: 67.22
# Text(0.5, 1.0, 'Load vs Displacement - Simulations')

# %%
'''
Start of cells focused on simulation data
'''
part_name = "Outcome3"
outcome_1 = np.array([
    [1.25, 0.018],
    [2.50, 0.037],
    [3.75, 0.055],
    [5.0, 0.073],
    [6.25, 0.092],
    [7.5, 0.110],
    [8.75, 0.128],
    [10.0, 0.147],
    [11.25, 0.165],
    [12.50, 0.183],
    [13.75, 0.202],
    [15.0, 0.220],
    [16.25, 0.238],
    [17.50, 0.257],
    [18.75, 0.275],
    [20.0, 0.293],
    [21.25, 0.312],
    [22.50, 0.330],
    [23.75, 0.348],
    [25.0, 0.367]
])
sim_loads_1 = []
sim_disps_1 = []
for val in outcome_1:
    sim_loads_1.append(val[0])
    sim_disps_1.append(val[1])

plt.plot(sim_disps_1, sim_loads_1)
sim_loads_1 = np.array(sim_loads_1)
sim_disps_1 = np.array(sim_disps_1)
m, b = np.polyfit(sim_disps_1, sim_loads_1, 1)
print(f"Stiffness of {part_name}: {round(m,2)}")
# Out:
# Stiffness of Outcome3: 68.17
